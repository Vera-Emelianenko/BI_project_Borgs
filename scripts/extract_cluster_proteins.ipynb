# %%
from Bio import Entrez
from Bio import SeqIO

# %%
Entrez.email = 'minotetrastichus@gmail.com'

# %%
prot_seqs=[]
with open('./Clusters.txt') as clusters_file: 
    cluster_number = 0
    print ('Cluster ', cluster_number)
    for line in clusters_file: 
        if line == '\n': 
            cluster_number +=1
            print ('\n\n Cluster ', cluster_number)
        else: 
            coordinates = line.split()[2]
            start = int(coordinates.split('_')[0])
            end = int(coordinates.split('_')[1])
            gb_id = line.split()[1]
            if int(start) > int (end): 
                start, end = end, start 
            print(f'Gb id: {gb_id}, start: {start}, end: {end}')
            handle = Entrez.efetch(db='nucleotide', rettype="gb", id=gb_id)
            for rec in SeqIO.parse(handle, "genbank"):
                for feature in rec.features:
                    if feature.type=='CDS':
                        if 'protein_id' in feature.qualifiers:
                            fstart = str(feature.location.start)
                            fstart = int(fstart.replace('<',''))

                            fend = str(feature.location.end)
                            fend = int(fend.replace('>',''))
                            
                            if fstart > fend: 
                                fstart, fend = fend, fstart 
                            if fstart >= start-10 and fend <= end+10:
                                
                                if 'product' not in feature.qualifiers:
                                    product = 'unknown'
                                else:
                                    product = feature.qualifiers["product"][0]
                                    
                                prot_id = feature.qualifiers["protein_id"][0]
                                print (f'Feature start: {fstart}, feature end: {fend}, product: {product}, prot_id: {prot_id}')
                                prot_seq = Entrez.efetch(db="protein", id=prot_id, retmode="text", rettype="fasta").read()
                                prot_seqs.append(prot_seq)
# Out:
# Cluster  0
# Gb id: CABMGN010000008.1, start: 240389, end: 241435
# Feature start: 240388, feature end: 241435, product: D-inositol-3-phosphate glycosyltransferase, prot_id: VVB80282.1
# Gb id: CABMGN010000008.1, start: 242848, end: 244005
# Feature start: 242847, feature end: 244005, product: Glycosyltransferase Gtf1, prot_id: VVB80288.1
# Gb id: CABMGN010000008.1, start: 244002, end: 244889
# Feature start: 244001, feature end: 244889, product: Glycosyltransferase AglE, prot_id: VVB80290.1
# Gb id: CABMGN010000008.1, start: 247150, end: 248259
# Feature start: 247149, feature end: 248259, product: Trehalose synthase, prot_id: VVB80296.1
# Gb id: CABMGN010000008.1, start: 249026, end: 250255
# Feature start: 249025, feature end: 250240, product: Polysaccharide biosynthesis protein, prot_id: VVB80300.1
#
#
#  Cluster  1
# Gb id: CABMIH010000075.1, start: 83777, end: 84511
# Feature start: 83776, feature end: 84511, product: Sulfite exporter TauE/SafE, prot_id: VVB96841.1
# Gb id: CABMIH010000075.1, start: 85252, end: 85641
# Feature start: 85251, feature end: 85641, product: Inosine-5'-monophosphate dehydrogenase, prot_id: VVB96843.1
# Gb id: CABMIH010000075.1, start: 85776, end: 86051
# Feature start: 85775, feature end: 86051, product: Uncharacterised protein, prot_id: VVB96845.1
# Gb id: CABMIH010000075.1, start: 86058, end: 87377
# Feature start: 86057, feature end: 87377, product: Light-independent protochlorophyllide reductase subunit B, prot_id: VVB96847.1
# Gb id: CABMIH010000075.1, start: 87378, end: 88748
# Feature start: 87377, feature end: 88748, product: Light-independent protochlorophyllide reductase subunit B, prot_id: VVB96848.1
#
#
#  Cluster  2
# Gb id: CABMII010000161.1, start: 18125, end: 18670
# Feature start: 18124, feature end: 18670, product: Pyruvate synthase subunit PorC, prot_id: VVB97632.1
# Gb id: CABMII010000161.1, start: 18667, end: 18927
# Feature start: 18666, feature end: 18927, product: Pyruvate synthase subunit PorD, prot_id: VVB97634.1
# Gb id: CABMII010000161.1, start: 18936, end: 20111
# Gb id: CABMII010000161.1, start: 20108, end: 20980
# Feature start: 20107, feature end: 20980, product: Pyruvate synthase subunit PorB, prot_id: VVB97638.1
#
#
#  Cluster  3
# Gb id: CABMII010000161.1, start: 41144, end: 42067
# Feature start: 41143, feature end: 42067, product: Uncharacterised protein, prot_id: VVB97671.1
# Gb id: CABMII010000161.1, start: 42067, end: 43098
# Feature start: 42066, feature end: 43098, product: UDP-N-acetylglucosamine 3-dehydrogenase, prot_id: VVB97672.1
# Gb id: CABMII010000161.1, start: 43095, end: 43547
# Feature start: 43094, feature end: 43547, product: Oligosaccharide biosynthesis protein Alg14 like protein, prot_id: VVB97673.1
# Gb id: CABMII010000161.1, start: 43544, end: 44020
# Feature start: 43543, feature end: 44020, product: UDP-N-acetylglucosamine--N-acetylmuramyl- (pentapeptide) pyrophosphoryl-undecaprenol N-acetylglucosamine transferase, prot_id: VVB97674.1
# Gb id: CABMII010000161.1, start: 45180, end: 46982
# Feature start: 45179, feature end: 46982, product: Uncharacterised protein, prot_id: VVB97676.1
#
#
#  Cluster  4
# Gb id: CABMIB010000088.1, start: 15442, end: 16836
# Gb id: CABMIB010000088.1, start: 17508, end: 18950
# Feature start: 17507, feature end: 18950, product: Uncharacterised protein, prot_id: VVB90560.1
# Gb id: CABMIB010000088.1, start: 21223, end: 22053
# Feature start: 21222, feature end: 22053, product: Prokaryotic cytochrome b561, prot_id: VVB90563.1
# Gb id: CABMIB010000088.1, start: 22056, end: 22811
#
#
#  Cluster  5
# Gb id: CABMIH010000065.1, start: 35277, end: 36746
# Feature start: 35276, feature end: 36746, product: Uncharacterised protein, prot_id: VVB96050.1
# Gb id: CABMIH010000065.1, start: 36754, end: 37116
# Feature start: 36753, feature end: 37116, product: Uncharacterised protein, prot_id: VVB96051.1
# Gb id: CABMIH010000065.1, start: 37118, end: 37771
# Feature start: 37117, feature end: 37771, product: Uncharacterised protein, prot_id: VVB96052.1
# Gb id: CABMIH010000065.1, start: 37759, end: 38247
# Feature start: 37758, feature end: 38247, product: Uncharacterised protein, prot_id: VVB96053.1
# Gb id: CABMIH010000065.1, start: 38256, end: 39116
# Feature start: 38255, feature end: 39116, product: Uncharacterised protein, prot_id: VVB96054.1
# Gb id: CABMIH010000065.1, start: 39116, end: 41050
# Feature start: 39115, feature end: 41050, product: Type II secretion system (T2SS), protein F, prot_id: VVB96055.1
# Gb id: CABMIH010000065.1, start: 41047, end: 42675
# Feature start: 41046, feature end: 42675, product: Type II/IV secretion system protein, prot_id: VVB96056.1
# Gb id: CABMIH010000065.1, start: 43545, end: 44411
# Feature start: 43544, feature end: 44411, product: Uncharacterised protein, prot_id: VVB96058.1
#
#
#  Cluster  6
# Gb id: CABMII010000013.1, start: 38911, end: 40116
# Feature start: 38910, feature end: 40116, product: Cytochrome c7 c, prot_id: VVB92524.1
# Gb id: CABMII010000013.1, start: 41182, end: 41847
# Feature start: 41181, feature end: 41853, product: Uncharacterised protein, prot_id: VVB92526.1
# Gb id: CABMII010000013.1, start: 41946, end: 43106
# Feature start: 41945, feature end: 43106, product: Uncharacterised protein, prot_id: VVB92527.1
# Gb id: CABMII010000013.1, start: 43257, end: 43610
# Feature start: 43256, feature end: 43571, product: Uncharacterised protein, prot_id: VVB92528.1
#
#
#  Cluster  7
# Gb id: CABMIB010000079.1, start: 3365, end: 4144
# Feature start: 3364, feature end: 4144, product: Uncharacterised protein, prot_id: VVB89876.1
# Gb id: CABMIB010000079.1, start: 4162, end: 7431
# Feature start: 4161, feature end: 7431, product: Uncharacterised protein, prot_id: VVB89879.1
# Gb id: CABMIB010000079.1, start: 7537, end: 8694
# Feature start: 7536, feature end: 8694, product: Uncharacterised protein, prot_id: VVB89881.1
# Gb id: CABMIB010000079.1, start: 8961, end: 9929
# Feature start: 8960, feature end: 9929, product: Uncharacterised protein, prot_id: VVB89883.1
# Gb id: CABMIB010000079.1, start: 9992, end: 10618
# Feature start: 9991, feature end: 10618, product: Uncharacterised protein, prot_id: VVB89885.1
#
#
#  Cluster  8
# Gb id: CR626856.1, start: 10828, end: 11862
# Feature start: 10827, feature end: 11862, product: hypothetical protein, prot_id: CAH04776.1
# Gb id: CR626856.1, start: 11917, end: 12966
# Feature start: 11916, feature end: 12966, product: hypothetical protein, prot_id: CAH04777.1
# Gb id: CR626856.1, start: 12968, end: 13981
# Feature start: 12967, feature end: 13981, product: hypothetical protein, prot_id: CAH04778.1
# Gb id: CR626856.1, start: 13992, end: 15047
# Feature start: 13991, feature end: 15047, product: hypothetical protein, prot_id: CAH04779.1
# Gb id: CR626856.1, start: 15054, end: 16049
# Feature start: 15053, feature end: 16004, product: hypothetical protein, prot_id: CAH04780.1
#
#
#  Cluster  9
# Gb id: CP009479.1, start: 1956101, end: 1956988
# Feature start: 1956100, feature end: 1956988, product: 2-ketoisovalerate ferredoxin oxidoreductase, prot_id: AKA49432.1
# Gb id: CP009479.1, start: 1956989, end: 1958167
# Feature start: 1956988, feature end: 1958158, product: pyruvate ferredoxin oxidoreductase, prot_id: AKA49433.1
# Gb id: CP009479.1, start: 1958164, end: 1958463
# Feature start: 1958163, feature end: 1958463, product: tungsten formylmethanofuran dehydrogenase, prot_id: AKA49434.1
# Gb id: CP009479.1, start: 1958467, end: 1959015
# Feature start: 1958466, feature end: 1959015, product: pyruvate ferredoxin oxidoreductase, prot_id: AKA49435.1
#
#
#  Cluster  10
# Gb id: CABMIB010000101.1, start: 2151, end: 3023
# Feature start: 2150, feature end: 3023, product: Glycosyltransferase AglG, prot_id: VVB91060.1
# Gb id: CABMIB010000101.1, start: 3016, end: 4725
# Gb id: CABMIB010000101.1, start: 7054, end: 8313
# Feature start: 7053, feature end: 8313, product: AMP-binding enzyme, prot_id: VVB91065.1
# Gb id: CABMIB010000101.1, start: 8398, end: 9558
# Feature start: 8397, feature end: 9558, product: NADP(+)-dependent glutamate dehydrogenase, prot_id: VVB91067.1
# Gb id: CABMIB010000101.1, start: 10444, end: 11271
# Feature start: 10443, feature end: 11271, product: Glycosyl hydrolase family 12, prot_id: VVB91071.1
#
#
#  Cluster  11
# Gb id: CABMCA010000104.1, start: 17516, end: 19762
# Feature start: 17515, feature end: 19762, product: Dolichyl-monophosphooligosaccharide--protein glycotransferase AglB, prot_id: VVB55858.1
# Gb id: CABMCA010000104.1, start: 19759, end: 21363
# Feature start: 19758, feature end: 21363, product: Uncharacterised protein, prot_id: VVB55859.1
# Gb id: CABMCA010000104.1, start: 21447, end: 22064
# Gb id: CABMCA010000104.1, start: 22067, end: 22498
# Feature start: 22066, feature end: 22498, product: Uncharacterised protein, prot_id: VVB55861.1
# Gb id: CABMCA010000104.1, start: 23312, end: 24037
# Feature start: 23311, feature end: 24037, product: Peptidase S24-like protein, prot_id: VVB55863.1
# Gb id: CABMCA010000104.1, start: 25599, end: 26612
# Feature start: 25598, feature end: 26612, product: Uncharacterised protein, prot_id: VVB55865.1
#
#
#  Cluster  12
# Gb id: CABMCA010000104.1, start: 35498, end: 36100
# Feature start: 35497, feature end: 36100, product: Uncharacterised protein, prot_id: VVB55876.1
# Gb id: CABMCA010000104.1, start: 36173, end: 36634
# Feature start: 36172, feature end: 36634, product: Uncharacterised protein, prot_id: VVB55877.1
# Gb id: CABMCA010000104.1, start: 37687, end: 39144
# Feature start: 37686, feature end: 39144, product: Uncharacterised protein, prot_id: VVB55880.1
# Gb id: CABMCA010000104.1, start: 39152, end: 39838
# Feature start: 39151, feature end: 39838, product: Peptidase S24-like protein, prot_id: VVB55881.1
# Gb id: CABMCA010000104.1, start: 39835, end: 40719
# Feature start: 39834, feature end: 40719, product: Cytochrome c7 c, prot_id: VVB55882.1
#
#
#  Cluster  13
# Gb id: CABMCA010000016.1, start: 22156, end: 22701
# Feature start: 22155, feature end: 22701, product: Pyruvate synthase subunit PorC, prot_id: VVB51377.1
# Gb id: CABMCA010000016.1, start: 22698, end: 22958
# Feature start: 22697, feature end: 22958, product: Pyruvate synthase subunit PorD, prot_id: VVB51378.1
# Gb id: CABMCA010000016.1, start: 22955, end: 24142
# Feature start: 22954, feature end: 24142, product: Pyruvate synthase subunit PorA, prot_id: VVB51379.1
# Gb id: CABMCA010000016.1, start: 24139, end: 25011
# Feature start: 24138, feature end: 25011, product: Pyruvate synthase subunit PorB, prot_id: VVB51380.1
#
#
#  Cluster  14
# Gb id: HQ706341.1, start: 34850, end: 36154
# Feature start: 34849, feature end: 36154, product: methyl-coenzyme M reductase subunit B, prot_id: AEV59713.1
# Gb id: HQ706341.1, start: 36172, end: 36648
# Feature start: 36282, feature end: 36648, product: methyl-coenzyme M reductase subunit D, prot_id: AEV59714.1
# Gb id: HQ706341.1, start: 37270, end: 38049
# Feature start: 37287, feature end: 38049, product: methyl-coenzyme M reductase subunit G, prot_id: AEV59716.1
# Gb id: HQ706341.1, start: 38057, end: 39763
# Feature start: 38056, feature end: 39763, product: methyl-coenzyme M reductase subunit A, prot_id: AEV59717.1
#
#
#  Cluster  15
# Gb id: CABMIH010000056.1, start: 8276, end: 9286
# Feature start: 8275, feature end: 9286, product: Glycosyl transferases group 1, prot_id: VVB94975.1
# Gb id: CABMIH010000056.1, start: 9286, end: 10452
# Feature start: 9285, feature end: 10407, product: Trehalose synthase, prot_id: VVB94977.1
# Gb id: CABMIH010000056.1, start: 10419, end: 11849
# Feature start: 10418, feature end: 11849, product: tRNA-2-methylthio-N(6)-dimethylallyladenosine synthase, prot_id: VVB94979.1
# Gb id: CABMIH010000056.1, start: 11858, end: 12853
# Feature start: 11857, feature end: 12853, product: Glycosyltransferase AglE, prot_id: VVB94981.1
#
#
#  Cluster  16
# Gb id: CABMIB010000043.1, start: 36704, end: 38041
# Feature start: 36703, feature end: 38041, product: Cytochrome c7 c, prot_id: VVB86935.1
# Gb id: CABMIB010000043.1, start: 39543, end: 40007
# Feature start: 39542, feature end: 40007, product: Uncharacterised protein, prot_id: VVB86941.1
# Gb id: CABMIB010000043.1, start: 41015, end: 42445
# Feature start: 41014, feature end: 42445, product: Uncharacterised protein, prot_id: VVB86945.1
# Gb id: CABMIB010000043.1, start: 42452, end: 43135
# Feature start: 42451, feature end: 43135, product: Peptidase S24-like protein, prot_id: VVB86947.1
# Gb id: CABMIB010000043.1, start: 43132, end: 44013
# Feature start: 43131, feature end: 44013, product: Cytochrome c7 c, prot_id: VVB86949.1
#
#
#  Cluster  17
# Gb id: CABMCU010000082.1, start: 8599, end: 9237
# Feature start: 8598, feature end: 9237, product: Pyruvate/ketoisovalerate oxidoreductases common subunit gamma, prot_id: VVB61346.1
# Gb id: CABMCU010000082.1, start: 9234, end: 9509
# Feature start: 9233, feature end: 9509, product: Ketoisovalerate oxidoreductase subunit VorD, prot_id: VVB61348.1
# Gb id: CABMCU010000082.1, start: 9506, end: 10660
# Feature start: 9505, feature end: 10660, product: Ketoisovalerate oxidoreductase subunit VorA, prot_id: VVB61350.1
# Gb id: CABMCU010000082.1, start: 10664, end: 11575
# Feature start: 10663, feature end: 11575, product: Ketoisovalerate oxidoreductase subunit VorB, prot_id: VVB61352.1
#
#
#  Cluster  18
# Gb id: CABMIB010000074.1, start: 66098, end: 67360
# Feature start: 66097, feature end: 67360, product: Polysaccharide biosynthesis protein, prot_id: VVB89702.1
# Gb id: CABMIB010000074.1, start: 67405, end: 68313
# Feature start: 67410, feature end: 68313, product: Glycosyltransferase AglD, prot_id: VVB89704.1
# Gb id: CABMIB010000074.1, start: 68420, end: 69391
# Feature start: 68419, feature end: 69391, product: Trehalose synthase, prot_id: VVB89707.1
# Gb id: CABMIB010000074.1, start: 71146, end: 72261
# Feature start: 71145, feature end: 72261, product: D-inositol-3-phosphate glycosyltransferase, prot_id: VVB89716.1
#
#
#  Cluster  19
# Gb id: KP308643.1, start: 96613, end: 97488
# Gb id: KP308643.1, start: 97479, end: 98108
# Gb id: KP308643.1, start: 98098, end: 99084
# Gb id: KP308643.1, start: 100907, end: 101665
#
#
#  Cluster  20
# Gb id: CABMCA010000042.1, start: 45039, end: 46343
# Feature start: 45038, feature end: 46343, product: Methyl-coenzyme M reductase subunit beta, prot_id: VVB52276.1
# Gb id: CABMCA010000042.1, start: 46358, end: 46879
# Feature start: 46357, feature end: 46879, product: Methyl-coenzyme M reductase II operon protein D, prot_id: VVB52278.1
# Gb id: CABMCA010000042.1, start: 46935, end: 47684
# Feature start: 46934, feature end: 47684, product: Methyl-coenzyme M reductase subunit gamma, prot_id: VVB52280.1
# Gb id: CABMCA010000042.1, start: 47695, end: 49386
# Feature start: 47694, feature end: 49386, product: Methyl-coenzyme M reductase subunit alpha, prot_id: VVB52282.1
#
#
#  Cluster  21
# Gb id: CABMIB010000105.1, start: 3020, end: 3565
# Feature start: 3019, feature end: 3565, product: Pyruvate synthase subunit PorC, prot_id: VVB91515.1
# Gb id: CABMIB010000105.1, start: 3562, end: 3822
# Feature start: 3561, feature end: 3822, product: Pyruvate synthase subunit PorD, prot_id: VVB91517.1
# Gb id: CABMIB010000105.1, start: 3831, end: 5006
# Gb id: CABMIB010000105.1, start: 5003, end: 5875
# Feature start: 5002, feature end: 5875, product: Pyruvate synthase subunit PorB, prot_id: VVB91521.1
#
#
#  Cluster  22
# Gb id: CABMCA010000104.1, start: 19759, end: 21363
# Feature start: 19758, feature end: 21363, product: Uncharacterised protein, prot_id: VVB55859.1
# Gb id: CABMCA010000104.1, start: 21384, end: 22064
# Feature start: 21383, feature end: 22064, product: Uncharacterised protein, prot_id: VVB55860.1
# Gb id: CABMCA010000104.1, start: 22067, end: 22498
# Feature start: 22066, feature end: 22498, product: Uncharacterised protein, prot_id: VVB55861.1
# Gb id: CABMCA010000104.1, start: 23312, end: 24037
# Feature start: 23311, feature end: 24037, product: Peptidase S24-like protein, prot_id: VVB55863.1
# Gb id: CABMCA010000104.1, start: 25599, end: 26612
# Feature start: 25598, feature end: 26612, product: Uncharacterised protein, prot_id: VVB55865.1
#
#
#  Cluster  23
# Gb id: CR626856.1, start: 10828, end: 11862
# Feature start: 10827, feature end: 11862, product: hypothetical protein, prot_id: CAH04776.1
# Gb id: CR626856.1, start: 11917, end: 12966
# Feature start: 11916, feature end: 12966, product: hypothetical protein, prot_id: CAH04777.1
# Gb id: CR626856.1, start: 12968, end: 13999
# Feature start: 12967, feature end: 13981, product: hypothetical protein, prot_id: CAH04778.1
# Gb id: CR626856.1, start: 13992, end: 15047
# Feature start: 13991, feature end: 15047, product: hypothetical protein, prot_id: CAH04779.1
# Gb id: CR626856.1, start: 15054, end: 16049
# Feature start: 15053, feature end: 16004, product: hypothetical protein, prot_id: CAH04780.1
#
#
#  Cluster  24
# Gb id: CABMIB010000079.1, start: 3365, end: 4144
# Feature start: 3364, feature end: 4144, product: Uncharacterised protein, prot_id: VVB89876.1
# Gb id: CABMIB010000079.1, start: 4162, end: 7431
# Feature start: 4161, feature end: 7431, product: Uncharacterised protein, prot_id: VVB89879.1
# Gb id: CABMIB010000079.1, start: 8961, end: 9929
# Feature start: 8960, feature end: 9929, product: Uncharacterised protein, prot_id: VVB89883.1
# Gb id: CABMIB010000079.1, start: 9992, end: 10618
# Feature start: 9991, feature end: 10618, product: Uncharacterised protein, prot_id: VVB89885.1
#
#
#  Cluster  25
# Gb id: CABMII010000005.1, start: 10731, end: 12665
# Feature start: 10730, feature end: 12665, product: Osmosensitive K+ channel His kinase sensor domain protein, prot_id: VVB92121.1
# Gb id: CABMII010000005.1, start: 12806, end: 13372
# Feature start: 12805, feature end: 13372, product: Potassium-transporting ATPase KdpC subunit, prot_id: VVB92123.1
# Gb id: CABMII010000005.1, start: 14168, end: 16264
# Feature start: 14167, feature end: 16249, product: Potassium-transporting ATPase ATP-binding subunit, prot_id: VVB92125.1
# Gb id: CABMII010000005.1, start: 16251, end: 17975
# Feature start: 16250, feature end: 17984, product: Potassium-transporting ATPase potassium-binding subunit, prot_id: VVB92126.1
#
#
#  Cluster  26
# Gb id: CABMIB010000043.1, start: 36704, end: 38041
# Feature start: 36703, feature end: 38041, product: Cytochrome c7 c, prot_id: VVB86935.1
# Gb id: CABMIB010000043.1, start: 39543, end: 40007
# Feature start: 39542, feature end: 40007, product: Uncharacterised protein, prot_id: VVB86941.1
# Gb id: CABMIB010000043.1, start: 41015, end: 42445
# Feature start: 41014, feature end: 42445, product: Uncharacterised protein, prot_id: VVB86945.1
# Gb id: CABMIB010000043.1, start: 42452, end: 43135
# Feature start: 42451, feature end: 43135, product: Peptidase S24-like protein, prot_id: VVB86947.1
# Gb id: CABMIB010000043.1, start: 43132, end: 44013
# Feature start: 43131, feature end: 44013, product: Cytochrome c7 c, prot_id: VVB86949.1
#
#
#  Cluster  27
# Gb id: CABMCA010000104.1, start: 33807, end: 35114
# Feature start: 33806, feature end: 35114, product: Cytochrome c7 c, prot_id: VVB55874.1
# Gb id: CABMCA010000104.1, start: 35498, end: 36100
# Feature start: 35497, feature end: 36100, product: Uncharacterised protein, prot_id: VVB55876.1
# Gb id: CABMCA010000104.1, start: 36173, end: 36634
# Feature start: 36172, feature end: 36634, product: Uncharacterised protein, prot_id: VVB55877.1
# Gb id: CABMCA010000104.1, start: 37687, end: 39144
# Feature start: 37686, feature end: 39144, product: Uncharacterised protein, prot_id: VVB55880.1
# Gb id: CABMCA010000104.1, start: 39152, end: 39838
# Feature start: 39151, feature end: 39838, product: Peptidase S24-like protein, prot_id: VVB55881.1
# Gb id: CABMCA010000104.1, start: 39835, end: 40719
# Feature start: 39834, feature end: 40719, product: Cytochrome c7 c, prot_id: VVB55882.1
#
#
#  Cluster  28
# Gb id: CABMIB010000079.1, start: 3365, end: 4144
# Feature start: 3364, feature end: 4144, product: Uncharacterised protein, prot_id: VVB89876.1
# Gb id: CABMIB010000079.1, start: 4162, end: 7431
# Feature start: 4161, feature end: 7431, product: Uncharacterised protein, prot_id: VVB89879.1
# Gb id: CABMIB010000079.1, start: 7537, end: 8694
# Feature start: 7536, feature end: 8694, product: Uncharacterised protein, prot_id: VVB89881.1
# Gb id: CABMIB010000079.1, start: 8961, end: 9929
# Feature start: 8960, feature end: 9929, product: Uncharacterised protein, prot_id: VVB89883.1
# Gb id: CABMIB010000079.1, start: 9992, end: 10618
# Feature start: 9991, feature end: 10618, product: Uncharacterised protein, prot_id: VVB89885.1
#
#
#  Cluster  29
# Gb id: CABMIB010000101.1, start: 2115, end: 3023
# Feature start: 2150, feature end: 3023, product: Glycosyltransferase AglG, prot_id: VVB91060.1
# Gb id: CABMIB010000101.1, start: 2989, end: 4725
# Feature start: 2988, feature end: 4725, product: Uncharacterised protein, prot_id: VVB91061.1
# Gb id: CABMIB010000101.1, start: 7054, end: 8313
# Feature start: 7053, feature end: 8313, product: AMP-binding enzyme, prot_id: VVB91065.1
# Gb id: CABMIB010000101.1, start: 8398, end: 9558
# Feature start: 8397, feature end: 9558, product: NADP(+)-dependent glutamate dehydrogenase, prot_id: VVB91067.1
# Gb id: CABMIB010000101.1, start: 10444, end: 11271
# Feature start: 10443, feature end: 11271, product: Glycosyl hydrolase family 12, prot_id: VVB91071.1
#
#
#  Cluster  30
# Gb id: CABMCA010000104.1, start: 19759, end: 21363
# Feature start: 19758, feature end: 21363, product: Uncharacterised protein, prot_id: VVB55859.1
# Gb id: CABMCA010000104.1, start: 21384, end: 22064
# Feature start: 21383, feature end: 22064, product: Uncharacterised protein, prot_id: VVB55860.1
# Gb id: CABMCA010000104.1, start: 22067, end: 22498
# Feature start: 22066, feature end: 22498, product: Uncharacterised protein, prot_id: VVB55861.1
# Gb id: CABMCA010000104.1, start: 23312, end: 24037
# Feature start: 23311, feature end: 24037, product: Peptidase S24-like protein, prot_id: VVB55863.1
# Gb id: CABMCA010000104.1, start: 24062, end: 25630
# Feature start: 24061, feature end: 25630, product: Cytochrome c7 c, prot_id: VVB55864.1
# Gb id: CABMCA010000104.1, start: 25599, end: 26612
# Feature start: 25598, feature end: 26612, product: Uncharacterised protein, prot_id: VVB55865.1
#
#
#  Cluster  31
# Gb id: CABMIB010000079.1, start: 4162, end: 7431
# Feature start: 4161, feature end: 7431, product: Uncharacterised protein, prot_id: VVB89879.1
# Gb id: CABMIB010000079.1, start: 7537, end: 8694
# Feature start: 7536, feature end: 8694, product: Uncharacterised protein, prot_id: VVB89881.1
# Gb id: CABMIB010000079.1, start: 8961, end: 9929
# Feature start: 8960, feature end: 9929, product: Uncharacterised protein, prot_id: VVB89883.1
# Gb id: CABMIB010000079.1, start: 9992, end: 10618
# Feature start: 9991, feature end: 10618, product: Uncharacterised protein, prot_id: VVB89885.1

# %%
with open("cluster_proteins_unique.fasta", "w") as ouf:
    for protein_seq in set(prot_seqs):
        ouf.write(protein_seq)
